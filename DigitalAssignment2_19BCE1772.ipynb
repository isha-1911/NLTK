# %%
import nltk, re, pprint
from nltk import word_tokenize

# %% [markdown]
# ###  Reading and tokenizing the text file

# %%
textfile = open('corpora_1772.txt','r')
textfile.read()
# Out:
# 'Porterâ€™s factor conditions for countriesâ€™ competitiveness are demand condition, related industries, firmâ€™s strategy, and the level of rivalry. Australia has been challenged for the trophy and there was an increased demand for the country to produce results in the game. The country through several failures to lift the trophy had learned its weaknesses, and in 2005, it went to the games with polished strategies to face their rivals. This led to its victory.\nThe location of a business affects the level of its competitiveness. When choosing a location, business people should analyze the level of demand for their products. It should be located in an area that has a high demand for its products.\n\nSecondly, the level of rivalry and the influence of related industries influence the location of a business. Generally, a business should ensure that it is established in an area with minimal rivalry or an area in which it can face external rivalry. The existence of related businesses like suppliers also affects the location. Closeness to suppliers and distribution channels is required when establishing a business.'

# %%
import nltk
file_content = open('corpora_1772.txt').read()
tokens = nltk.word_tokenize(file_content)
print(tokens)
# Out:
# ['Porterâ€™s', 'factor', 'conditions', 'for', 'countriesâ€™', 'competitiveness', 'are', 'demand', 'condition', ',', 'related', 'industries', ',', 'firmâ€™s', 'strategy', ',', 'and', 'the', 'level', 'of', 'rivalry', '.', 'Australia', 'has', 'been', 'challenged', 'for', 'the', 'trophy', 'and', 'there', 'was', 'an', 'increased', 'demand', 'for', 'the', 'country', 'to', 'produce', 'results', 'in', 'the', 'game', '.', 'The', 'country', 'through', 'several', 'failures', 'to', 'lift', 'the', 'trophy', 'had', 'learned', 'its', 'weaknesses', ',', 'and', 'in', '2005', ',', 'it', 'went', 'to', 'the', 'games', 'with', 'polished', 'strategies', 'to', 'face', 'their', 'rivals', '.', 'This', 'led', 'to', 'its', 'victory', '.', 'The', 'location', 'of', 'a', 'business', 'affects', 'the', 'level', 'of', 'its', 'competitiveness', '.', 'When', 'choosing', 'a', 'location', ',', 'business', 'people', 'should', 'analyze', 'the', 'level', 'of', 'demand', 'for', 'their', 'products', '.', 'It', 'should', 'be', 'located', 'in', 'an', 'area', 'that', 'has', 'a', 'high', 'demand', 'for', 'its', 'products', '.', 'Secondly', ',', 'the', 'level', 'of', 'rivalry', 'and', 'the', 'influence', 'of', 'related', 'industries', 'influence', 'the', 'location', 'of', 'a', 'business', '.', 'Generally', ',', 'a', 'business', 'should', 'ensure', 'that', 'it', 'is', 'established', 'in', 'an', 'area', 'with', 'minimal', 'rivalry', 'or', 'an', 'area', 'in', 'which', 'it', 'can', 'face', 'external', 'rivalry', '.', 'The', 'existence', 'of', 'related', 'businesses', 'like', 'suppliers', 'also', 'affects', 'the', 'location', '.', 'Closeness', 'to', 'suppliers', 'and', 'distribution', 'channels', 'is', 'required', 'when', 'establishing', 'a', 'business', '.']

# %% [markdown]
# ### Word segmentation

# %%
# getting the word segment
import wordsegment
from wordsegment import load, segment
load()
segment(file_content)
# Out:
# ['porters',
#  'factor',
#  'conditions',
#  'for',
#  'countries',
#  'competitiveness',
#  'are',
#  'demand',
#  'condition',
#  'related',
#  'industries',
#  'firms',
#  'strategy',
#  'and',
#  'the',
#  'level',
#  'of',
#  'rivalry',
#  'australia',
#  'has',
#  'been',
#  'challenged',
#  'for',
#  'the',
#  'trophy',
#  'and',
#  'there',
#  'was',
#  'an',
#  'increased',
#  'demand',
#  'for',
#  'the',
#  'country',
#  'to',
#  'produce',
#  'results',
#  'in',
#  'the',
#  'game',
#  'the',
#  'country',
#  'through',
#  'several',
#  'failures',
#  'to',
#  'lift',
#  'the',
#  'trophy',
#  'had',
#  'learned',
#  'its',
#  'weaknesses',
#  'and',
#  'in2005',
#  'it',
#  'went',
#  'to',
#  'the',
#  'games',
#  'with',
#  'polished',
#  'strategies',
#  'to',
#  'face',
#  'their',
#  'rivals',
#  'this',
#  'led',
#  'to',
#  'its',
#  'victory',
#  'the',
#  'location',
#  'of',
#  'a',
#  'business',
#  'affects',
#  'the',
#  'level',
#  'of',
#  'its',
#  'competitiveness',
#  'when',
#  'choosing',
#  'a',
#  'location',
#  'business',
#  'people',
#  'should',
#  'analyze',
#  'the',
#  'level',
#  'of',
#  'demand',
#  'for',
#  'their',
#  'products',
#  'it',
#  'should',
#  'be',
#  'located',
#  'in',
#  'an',
#  'area',
#  'that',
#  'has',
#  'a',
#  'high',
#  'demand',
#  'for',
#  'its',
#  'products',
#  'secondly',
#  'the',
#  'level',
#  'of',
#  'rivalry',
#  'and',
#  'the',
#  'influence',
#  'of',
#  'related',
#  'industries',
#  'influence',
#  'the',
#  'location',
#  'of',
#  'a',
#  'business',
#  'generally',
#  'a',
#  'business',
#  'should',
#  'ensure',
#  'that',
#  'it',
#  'is',
#  'established',
#  'in',
#  'an',
#  'area',
#  'with',
#  'minimal',
#  'rivalry',
#  'or',
#  'an',
#  'area',
#  'in',
#  'which',
#  'it',
#  'can',
#  'face',
#  'external',
#  'rivalry',
#  'the',
#  'existence',
#  'of',
#  'related',
#  'businesses',
#  'like',
#  'suppliers',
#  'also',
#  'affects',
#  'the',
#  'location',
#  'closeness',
#  'to',
#  'suppliers',
#  'and',
#  'distribution',
#  'channels',
#  'is',
#  'required',
#  'when',
#  'establishing',
#  'a',
#  'business']

# %% [markdown]
# ### Sentence Segementation

# %%
sentences = nltk.sent_tokenize(file_content)

# %%
sentences
# Out:
# ['Porterâ€™s factor conditions for countriesâ€™ competitiveness are demand condition, related industries, firmâ€™s strategy, and the level of rivalry.',
#  'Australia has been challenged for the trophy and there was an increased demand for the country to produce results in the game.',
#  'The country through several failures to lift the trophy had learned its weaknesses, and in 2005, it went to the games with polished strategies to face their rivals.',
#  'This led to its victory.',
#  'The location of a business affects the level of its competitiveness.',
#  'When choosing a location, business people should analyze the level of demand for their products.',
#  'It should be located in an area that has a high demand for its products.',
#  'Secondly, the level of rivalry and the influence of related industries influence the location of a business.',
#  'Generally, a business should ensure that it is established in an area with minimal rivalry or an area in which it can face external rivalry.',
#  'The existence of related businesses like suppliers also affects the location.',
#  'Closeness to suppliers and distribution channels is required when establishing a business.']

# %% [markdown]
# ### Convert to lowercase

# %%
lower_tokens = [token.lower() for token in tokens]
lower_tokens
# Out:
# ['porterâ€™s',
#  'factor',
#  'conditions',
#  'for',
#  'countriesâ€™',
#  'competitiveness',
#  'are',
#  'demand',
#  'condition',
#  ',',
#  'related',
#  'industries',
#  ',',
#  'firmâ€™s',
#  'strategy',
#  ',',
#  'and',
#  'the',
#  'level',
#  'of',
#  'rivalry',
#  '.',
#  'australia',
#  'has',
#  'been',
#  'challenged',
#  'for',
#  'the',
#  'trophy',
#  'and',
#  'there',
#  'was',
#  'an',
#  'increased',
#  'demand',
#  'for',
#  'the',
#  'country',
#  'to',
#  'produce',
#  'results',
#  'in',
#  'the',
#  'game',
#  '.',
#  'the',
#  'country',
#  'through',
#  'several',
#  'failures',
#  'to',
#  'lift',
#  'the',
#  'trophy',
#  'had',
#  'learned',
#  'its',
#  'weaknesses',
#  ',',
#  'and',
#  'in',
#  '2005',
#  ',',
#  'it',
#  'went',
#  'to',
#  'the',
#  'games',
#  'with',
#  'polished',
#  'strategies',
#  'to',
#  'face',
#  'their',
#  'rivals',
#  '.',
#  'this',
#  'led',
#  'to',
#  'its',
#  'victory',
#  '.',
#  'the',
#  'location',
#  'of',
#  'a',
#  'business',
#  'affects',
#  'the',
#  'level',
#  'of',
#  'its',
#  'competitiveness',
#  '.',
#  'when',
#  'choosing',
#  'a',
#  'location',
#  ',',
#  'business',
#  'people',
#  'should',
#  'analyze',
#  'the',
#  'level',
#  'of',
#  'demand',
#  'for',
#  'their',
#  'products',
#  '.',
#  'it',
#  'should',
#  'be',
#  'located',
#  'in',
#  'an',
#  'area',
#  'that',
#  'has',
#  'a',
#  'high',
#  'demand',
#  'for',
#  'its',
#  'products',
#  '.',
#  'secondly',
#  ',',
#  'the',
#  'level',
#  'of',
#  'rivalry',
#  'and',
#  'the',
#  'influence',
#  'of',
#  'related',
#  'industries',
#  'influence',
#  'the',
#  'location',
#  'of',
#  'a',
#  'business',
#  '.',
#  'generally',
#  ',',
#  'a',
#  'business',
#  'should',
#  'ensure',
#  'that',
#  'it',
#  'is',
#  'established',
#  'in',
#  'an',
#  'area',
#  'with',
#  'minimal',
#  'rivalry',
#  'or',
#  'an',
#  'area',
#  'in',
#  'which',
#  'it',
#  'can',
#  'face',
#  'external',
#  'rivalry',
#  '.',
#  'the',
#  'existence',
#  'of',
#  'related',
#  'businesses',
#  'like',
#  'suppliers',
#  'also',
#  'affects',
#  'the',
#  'location',
#  '.',
#  'closeness',
#  'to',
#  'suppliers',
#  'and',
#  'distribution',
#  'channels',
#  'is',
#  'required',
#  'when',
#  'establishing',
#  'a',
#  'business',
#  '.']

# %% [markdown]
# ### •	Stop words removal

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'his', 'hadn', "weren't", 'not', "wasn't", 'is', 'into', 'wouldn', 'theirs', 'such', 'my', 're', 'how', 'ma', 'we', "couldn't", 'myself', 'isn', "that'll", 'themselves', "won't", 'again', 'herself', 'mightn', 'during', 'some', 'your', 'by', 'its', 'out', 'has', 'why', "you're", 'nor', 'are', 'their', 'did', 'will', 'few', 'other', 'until', 'they', 'been', 'haven', "mightn't", 'doing', 'all', 'the', 's', 'i', 'or', 'too', 'but', 'off', 'an', 'hers', 't', 'having', 'who', 'were', 'about', 'then', 'now', 'here', 'do', "mustn't", 'any', 've', 'if', 'after', 'which', 'when', 'against', 'couldn', 'of', 'very', 'and', "you've", 'ours', 'those', 'was', 'up', 'down', 'this', 'does', "shouldn't", 'himself', "haven't", 'm', 'these', "you'll", 'them', 'for', 'd', 'ourselves', 'shan', 'him', "you'd", 'yourselves', "should've", 'have', 'aren', 'wasn', 'just', 'being', 'than', 'most', 'while', 'didn', "wouldn't", "doesn't", "didn't", 'whom', 'each', 'a', 'from', "isn't", 'only', 'won', 'on', 'both', 'had', 'there', 'once', 'as', 'needn', 'through', 'doesn', 'because', 'under', 'to', 'hasn', 'between', 'she', 'it', 'with', 'below', 'so', 'should', 'll', "aren't", 'own', 'weren', 'same', 'o', "needn't", 'what', "hasn't", 'he', "don't", 'don', 'ain', 'itself', 'before', 'mustn', 'yourself', 'more', 'our', "hadn't", 'be', 'you', 'y', 'can', 'where', 'at', 'over', "shan't", 'shouldn', 'me', 'am', 'further', "it's", 'yours', 'above', 'her', "she's", 'in', 'no', 'that'}

# %%
filtered_sentence = [w for w in tokens if not w.lower() in stop_words]
  
filtered_sentence = []
for w in lower_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

print(filtered_sentence)
# Out:
# ['porterâ€™s', 'factor', 'conditions', 'countriesâ€™', 'competitiveness', 'demand', 'condition', ',', 'related', 'industries', ',', 'firmâ€™s', 'strategy', ',', 'level', 'rivalry', '.', 'australia', 'challenged', 'trophy', 'increased', 'demand', 'country', 'produce', 'results', 'game', '.', 'country', 'several', 'failures', 'lift', 'trophy', 'learned', 'weaknesses', ',', '2005', ',', 'went', 'games', 'polished', 'strategies', 'face', 'rivals', '.', 'led', 'victory', '.', 'location', 'business', 'affects', 'level', 'competitiveness', '.', 'choosing', 'location', ',', 'business', 'people', 'analyze', 'level', 'demand', 'products', '.', 'located', 'area', 'high', 'demand', 'products', '.', 'secondly', ',', 'level', 'rivalry', 'influence', 'related', 'industries', 'influence', 'location', 'business', '.', 'generally', ',', 'business', 'ensure', 'established', 'area', 'minimal', 'rivalry', 'area', 'face', 'external', 'rivalry', '.', 'existence', 'related', 'businesses', 'like', 'suppliers', 'also', 'affects', 'location', '.', 'closeness', 'suppliers', 'distribution', 'channels', 'required', 'establishing', 'business', '.']

# %% [markdown]
# ### Stemming

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# getting the stem words from the list of filtered words
for w in filtered_sentence:
    print(w, " : ", ps.stem(w))
# Out:
# recently  :  recent
# completed  :  complet
# bachelorsâ€™s  :  bachelorsâ€™
# degree  :  degre
# nursing  :  nurs
# currently  :  current
# looking  :  look
# suitable  :  suitabl
# long-term  :  long-term
# employment  :  employ
# .  :  .
# hardworking  :  hardwork
# person  :  person
# great  :  great
# personality  :  person
# benchmarked  :  benchmark
# excellent  :  excel
# interpersonal  :  interperson
# skills  :  skill
# helped  :  help
# score  :  score
# great  :  great
# successes  :  success
# past  :  past
# .  :  .
# college  :  colleg
# held  :  held
# several  :  sever
# practical  :  practic
# exposures  :  exposur
# different  :  differ
# hospitals  :  hospit
# ,  :  ,
# received  :  receiv
# favorable  :  favor
# comments  :  comment
# staff  :  staff
# management  :  manag
# .  :  .
# recently  :  recent
# moved  :  move
# area  :  area
# .  :  .
# institution  :  institut
# brought  :  brought
# attention  :  attent
# one  :  one
# instructors  :  instructor
# college  :  colleg
# ,  :  ,
# said  :  said
# currently  :  current
# hiring  :  hire
# additional  :  addit
# staff  :  staff
# due  :  due
# increase  :  increas
# patient  :  patient
# numbers  :  number
# .  :  .
# record  :  record
# providing  :  provid
# quality  :  qualiti
# timely  :  time
# services  :  servic
# patients  :  patient
# makes  :  make
# desire  :  desir
# part  :  part
# team  :  team
# .  :  .
# suitable  :  suitabl
# vacancy  :  vacanc
# ,  :  ,
# please  :  pleas
# let  :  let
# know  :  know
# .  :  .
# grateful  :  grate
# speak  :  speak
# time  :  time
# .  :  .
# enthusiastic  :  enthusiast
# exploring  :  explor
# opportunities  :  opportun
# institution  :  institut
# look  :  look
# forward  :  forward
# meeting  :  meet
# .  :  .

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

for w in filtered_sentence:
    print(w, " : ", lemmatizer.lemmatize(w))
# Out:
# recently  :  recently
# completed  :  completed
# bachelorsâ€™s  :  bachelorsâ€™s
# degree  :  degree
# nursing  :  nursing
# currently  :  currently
# looking  :  looking
# suitable  :  suitable
# long-term  :  long-term
# employment  :  employment
# .  :  .
# hardworking  :  hardworking
# person  :  person
# great  :  great
# personality  :  personality
# benchmarked  :  benchmarked
# excellent  :  excellent
# interpersonal  :  interpersonal
# skills  :  skill
# helped  :  helped
# score  :  score
# great  :  great
# successes  :  success
# past  :  past
# .  :  .
# college  :  college
# held  :  held
# several  :  several
# practical  :  practical
# exposures  :  exposure
# different  :  different
# hospitals  :  hospital
# ,  :  ,
# received  :  received
# favorable  :  favorable
# comments  :  comment
# staff  :  staff
# management  :  management
# .  :  .
# recently  :  recently
# moved  :  moved
# area  :  area
# .  :  .
# institution  :  institution
# brought  :  brought
# attention  :  attention
# one  :  one
# instructors  :  instructor
# college  :  college
# ,  :  ,
# said  :  said
# currently  :  currently
# hiring  :  hiring
# additional  :  additional
# staff  :  staff
# due  :  due
# increase  :  increase
# patient  :  patient
# numbers  :  number
# .  :  .
# record  :  record
# providing  :  providing
# quality  :  quality
# timely  :  timely
# services  :  service
# patients  :  patient
# makes  :  make
# desire  :  desire
# part  :  part
# team  :  team
# .  :  .
# suitable  :  suitable
# vacancy  :  vacancy
# ,  :  ,
# please  :  please
# let  :  let
# know  :  know
# .  :  .
# grateful  :  grateful
# speak  :  speak
# time  :  time
# .  :  .
# enthusiastic  :  enthusiastic
# exploring  :  exploring
# opportunities  :  opportunity
# institution  :  institution
# look  :  look
# forward  :  forward
# meeting  :  meeting
# .  :  .

# %% [markdown]
# ### POS tagging

# %%
for sent in filtered_sentence:
    print(nltk.pos_tag(nltk.word_tokenize(sent)))
# Out:
# [('recently', 'RB')]
# [('completed', 'VBN')]
# [('bachelorsâ€™s', 'NN')]
# [('degree', 'NN')]
# [('nursing', 'NN')]
# [('currently', 'RB')]
# [('looking', 'VBG')]
# [('suitable', 'JJ')]
# [('long-term', 'JJ')]
# [('employment', 'NN')]
# [('.', '.')]
# [('hardworking', 'VBG')]
# [('person', 'NN')]
# [('great', 'JJ')]
# [('personality', 'NN')]
# [('benchmarked', 'VBN')]
# [('excellent', 'NN')]
# [('interpersonal', 'JJ')]
# [('skills', 'NNS')]
# [('helped', 'VBD')]
# [('score', 'NN')]
# [('great', 'JJ')]
# [('successes', 'NNS')]
# [('past', 'NN')]
# [('.', '.')]
# [('college', 'NN')]
# [('held', 'NN')]
# [('several', 'JJ')]
# [('practical', 'JJ')]
# [('exposures', 'NNS')]
# [('different', 'JJ')]
# [('hospitals', 'NNS')]
# [(',', ',')]
# [('received', 'VBN')]
# [('favorable', 'JJ')]
# [('comments', 'NNS')]
# [('staff', 'NN')]
# [('management', 'NN')]
# [('.', '.')]
# [('recently', 'RB')]
# [('moved', 'VBN')]
# [('area', 'NN')]
# [('.', '.')]
# [('institution', 'NN')]
# [('brought', 'NN')]
# [('attention', 'NN')]
# [('one', 'CD')]
# [('instructors', 'NNS')]
# [('college', 'NN')]
# [(',', ',')]
# [('said', 'VBD')]
# [('currently', 'RB')]
# [('hiring', 'VBG')]
# [('additional', 'JJ')]
# [('staff', 'NN')]
# [('due', 'JJ')]
# [('increase', 'NN')]
# [('patient', 'NN')]
# [('numbers', 'NNS')]
# [('.', '.')]
# [('record', 'NN')]
# [('providing', 'VBG')]
# [('quality', 'NN')]
# [('timely', 'RB')]
# [('services', 'NNS')]
# [('patients', 'NNS')]
# [('makes', 'VBZ')]
# [('desire', 'NN')]
# [('part', 'NN')]
# [('team', 'NN')]
# [('.', '.')]
# [('suitable', 'JJ')]
# [('vacancy', 'NN')]
# [(',', ',')]
# [('please', 'NN')]
# [('let', 'VB')]
# [('know', 'VB')]
# [('.', '.')]
# [('grateful', 'NN')]
# [('speak', 'NN')]
# [('time', 'NN')]
# [('.', '.')]
# [('enthusiastic', 'JJ')]
# [('exploring', 'VBG')]
# [('opportunities', 'NNS')]
# [('institution', 'NN')]
# [('look', 'NN')]
# [('forward', 'RB')]
# [('meeting', 'NN')]
# [('.', '.')]
